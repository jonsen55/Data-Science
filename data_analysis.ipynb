# %%
import pandas as pd

# %%
m = {
    'jon': ['horw','hoina']
}
data = pd.Series(m)

# %%
df = pd.read_csv('full.csv')

# %%
data_set = df.groupby(['Sex','Survived','Pclass'])
data_set.describe()
# Out:
#                        PassengerId                                         \
#                              count        mean         std    min     25%
# Sex    Survived Pclass
# female 0.0      1              3.0  325.000000  162.194328  178.0  238.00
#                 2              6.0  423.500000  322.594947   42.0  228.25
#                 3             72.0  440.375000  263.865813   15.0  224.00
#        1.0      1             91.0  473.967033  248.968916    2.0  296.00
#                 2             70.0  444.785714  238.617023   10.0  280.75
#                 3             72.0  359.083333  266.188419    3.0  138.75
# male   0.0      1             77.0  413.623377  255.663741    7.0  171.00
#                 2             91.0  454.010989  255.021371   21.0  231.00
#                 3            300.0  456.750000  263.247078    1.0  206.25
#        1.0      1             45.0  527.777778  215.633410   24.0  431.00
# ...
